# %%
import math
import warnings
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model
from sklearn.cross_decomposition import PLSRegression
# %matplotlib inline
sns.set_style('white')
warnings.filterwarnings(
    action="ignore",
    module="scipy",
    message="^internal gelsd")

# %%
n = 1000
p = 10
X = np.random.normal(size=n * p).reshape((n, p))
y = X[:, 0] + 2 * X[:, 1] + np.random.normal(size=n * 1) + 5

# %%
regr = linear_model.LinearRegression()
regr.fit(X, y)
Y_pred = regr.predict(X)

# %%
print('R-squared regression:', regr.score(X, y))
pls = PLSRegression(n_components=3)
pls.fit(X, y)
Y_PLS_pred = pls.predict(X)
print('R-squared PLSR:', pls.score(X, y))

plt.scatter(Y_pred, Y_PLS_pred)
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.8427053543834102
# R-squared PLSR: 0.8427053185526798

# %%
print('R-squared regression:', regr.score(X, y))
pls = PLSRegression(n_components=7)
pls.fit(X, y)
Y_PLS_pred2 = pls.predict(X)
print('R-squared PLSR:', pls.score(X, y))

plt.scatter(Y_pred, Y_PLS_pred)
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.8427053543834102
# R-squared PLSR: 0.8427053543834102

# %%
print('R-squared regression:', regr.score(X, y))
pls = PLSRegression(n_components=1)
pls.fit(X, y)
Y_PLS_pred = pls.predict(X)
print('R-squared PLSR:', pls.score(X, y))

plt.scatter(Y_pred, Y_PLS_pred)
plt.xlabel('Predicted by original 10 features')
plt.ylabel('Predicted by 3 features')
plt.title('Comparing LR and PLSR predictions')
plt.show()
# Out:
# R-squared regression: 0.8427053543834102
# R-squared PLSR: 0.8395371189141313
